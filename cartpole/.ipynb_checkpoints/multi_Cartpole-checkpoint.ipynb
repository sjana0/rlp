# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = 'CartPole-v0'
log_path = os.path.join('/home/kchn/rlp/cartpole/multi/Training', 'Logs')

# %%
for i in range(1, 11):
    print("Environment number", i)
    env = make_vec_env(environment_name, n_envs=i, seed=0)
    mdl = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
    mdl.learn(total_timesteps=100000)
    print(evaluate_policy(mdl, env, n_eval_episodes=10, render=True))
    env.close()
# Out:
# Environment number 1
# Using cuda device
# Logging to /home/kchn/rlp/cartpole/multi/Training/Logs/PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 21.8     |
# | time/              |          |
# |    fps             | 2036     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26          |
# |    ep_rew_mean          | 26          |
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008424005 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00954    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.13        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 49.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.5        |
# |    ep_rew_mean          | 32.5        |
# | time/                   |             |
# |    fps                  | 1245        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008376224 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.0738      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 37.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 45.5         |
# |    ep_rew_mean          | 45.5         |
# | time/                   |              |
# |    fps                  | 1185         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0128691755 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.633       |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0244      |
# |    value_loss           | 50.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.2        |
# |    ep_rew_mean          | 60.2        |
# | time/                   |             |
# |    fps                  | 1148        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010079714 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.604      |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 67.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.9        |
# |    ep_rew_mean          | 74.9        |
# | time/                   |             |
# |    fps                  | 1122        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008235932 |
# |    clip_fraction        | 0.0669      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 61          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.8         |
# |    ep_rew_mean          | 91.8         |
# | time/                   |              |
# |    fps                  | 1118         |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0068521956 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.595       |
# |    explained_variance   | 0.592        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.95         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00678     |
# |    value_loss           | 43.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | 109          |
# | time/                   |              |
# |    fps                  | 1107         |
# |    iterations           | 8            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0053444654 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.351        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.4         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00722     |
# |    value_loss           | 59.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 125          |
# |    ep_rew_mean          | 125          |
# | time/                   |              |
# |    fps                  | 1101         |
# |    iterations           | 9            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0014623865 |
# |    clip_fraction        | 0.00537      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.349        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.7          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 37.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 1092        |
# |    iterations           | 10          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005369777 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.34        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00841    |
# |    value_loss           | 38.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | 153          |
# | time/                   |              |
# |    fps                  | 1082         |
# |    iterations           | 11           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0070141363 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | 0.793        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.7         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00711     |
# |    value_loss           | 26.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 167          |
# |    ep_rew_mean          | 167          |
# | time/                   |              |
# |    fps                  | 1073         |
# |    iterations           | 12           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0051136077 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.565       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.87         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00973     |
# |    value_loss           | 6.84         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 176          |
# | time/                   |              |
# |    fps                  | 1070         |
# |    iterations           | 13           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0071861558 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.549       |
# |    explained_variance   | 0.00756      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.8         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00521     |
# |    value_loss           | 42.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 183          |
# |    ep_rew_mean          | 183          |
# | time/                   |              |
# |    fps                  | 1070         |
# |    iterations           | 14           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0011878225 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | 0.691        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 31.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 185         |
# | time/                   |             |
# |    fps                  | 1071        |
# |    iterations           | 15          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006950941 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.965       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 4.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 189         |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 1073        |
# |    iterations           | 16          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007635312 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.153       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 1.29        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 192          |
# |    ep_rew_mean          | 192          |
# | time/                   |              |
# |    fps                  | 1072         |
# |    iterations           | 17           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0025925785 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.534       |
# |    explained_variance   | 0.0924       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 0.719        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 1070        |
# |    iterations           | 18          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004126276 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0816      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00337    |
# |    value_loss           | 0.488       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 196          |
# |    ep_rew_mean          | 196          |
# | time/                   |              |
# |    fps                  | 1071         |
# |    iterations           | 19           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0052211764 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0244       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 0.305        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | 196         |
# | time/                   |             |
# |    fps                  | 1072        |
# |    iterations           | 20          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006743279 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.521      |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0462      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00503    |
# |    value_loss           | 0.206       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 1073         |
# |    iterations           | 21           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0029572952 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0459       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 0.14         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 1073         |
# |    iterations           | 22           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0042943163 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0135       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 0.0915       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 23          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004133208 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.496      |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00987     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 0.0616      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1077        |
# |    iterations           | 24          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005183759 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.503      |
# |    explained_variance   | -0.0394     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0341      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00137    |
# |    value_loss           | 0.04        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1077         |
# |    iterations           | 25           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0019060627 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | -0.0577      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000736    |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000101    |
# |    value_loss           | 0.0267       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 26          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.002496758 |
# |    clip_fraction        | 0.0264      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.496      |
# |    explained_variance   | 0.0192      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00691     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00217    |
# |    value_loss           | 0.0183      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1077        |
# |    iterations           | 27          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.002296494 |
# |    clip_fraction        | 0.0126      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | 0.028       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00319     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 28          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.003176739 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.475      |
# |    explained_variance   | 0.0482      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.011      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 0.00855     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1071        |
# |    iterations           | 29          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.001613367 |
# |    clip_fraction        | 0.00635     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.491      |
# |    explained_variance   | -0.0318     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00314     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.000653   |
# |    value_loss           | 0.00579     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 30          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004428402 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.491      |
# |    explained_variance   | -0.0305     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 0.00417     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1065         |
# |    iterations           | 31           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0028043818 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.496       |
# |    explained_variance   | -0.0677      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0115      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 0.0028       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1060         |
# |    iterations           | 32           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0015599595 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.501       |
# |    explained_variance   | -0.0506      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00204     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -8.95e-05    |
# |    value_loss           | 0.00197      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1058        |
# |    iterations           | 33          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.006365826 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.49       |
# |    explained_variance   | 0.00596     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0206     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 0.00138     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1057        |
# |    iterations           | 34          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004269494 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | -0.0634     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00505     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00207    |
# |    value_loss           | 0.001       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1056         |
# |    iterations           | 35           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0047170045 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.475       |
# |    explained_variance   | -0.0321      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000748    |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00402     |
# |    value_loss           | 0.000764     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1053         |
# |    iterations           | 36           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0018489324 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | -0.0667      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0051      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000751    |
# |    value_loss           | 0.000545     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1049         |
# |    iterations           | 37           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0020020173 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.492       |
# |    explained_variance   | -0.0975      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00622     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000474    |
# |    value_loss           | 0.000385     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1049         |
# |    iterations           | 38           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0054104337 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.454       |
# |    explained_variance   | -0.0415      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000798     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 0.000291     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1047         |
# |    iterations           | 39           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0022873287 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.464       |
# |    explained_variance   | -0.172       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00395     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 0.000205     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 40          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.002789237 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.436      |
# |    explained_variance   | -0.16       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00546     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 0.000146    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1040         |
# |    iterations           | 41           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0025536492 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.453       |
# |    explained_variance   | -0.0587      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0132      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 9.33e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1038         |
# |    iterations           | 42           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0018254569 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.445       |
# |    explained_variance   | -0.212       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00573     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -1.8e-05     |
# |    value_loss           | 6.93e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1038         |
# |    iterations           | 43           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0043299887 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.446       |
# |    explained_variance   | -0.135       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0253      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 5.32e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1037        |
# |    iterations           | 44          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004203439 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.417      |
# |    explained_variance   | -0.199      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00774    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00295    |
# |    value_loss           | 3.85e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1038        |
# |    iterations           | 45          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.003151258 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.398      |
# |    explained_variance   | -0.088      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00498    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 2.77e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1037         |
# |    iterations           | 46           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0018395069 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.392       |
# |    explained_variance   | -0.285       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00869     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000196    |
# |    value_loss           | 1.95e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1039         |
# |    iterations           | 47           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0040384764 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.398       |
# |    explained_variance   | -0.0607      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0142      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00618     |
# |    value_loss           | 1.79e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1039         |
# |    iterations           | 48           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0016424026 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.385       |
# |    explained_variance   | -0.288       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00131     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000872    |
# |    value_loss           | 1.13e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1039        |
# |    iterations           | 49          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.002697654 |
# |    clip_fraction        | 0.0369      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.369      |
# |    explained_variance   | -0.43       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00342     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 8.14e-06    |
# -----------------------------------------
# (200.0, 0.0)
# Environment number 2
# Using cuda device
# Logging to /home/kchn/rlp/cartpole/multi/Training/Logs/PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | 21       |
# | time/              |          |
# |    fps             | 3126     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 29.9        |
# | time/                   |             |
# |    fps                  | 1860        |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012941913 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.000251    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.69        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 29.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.7        |
# |    ep_rew_mean          | 44.7        |
# | time/                   |             |
# |    fps                  | 1595        |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013491248 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.77        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 28          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.5        |
# |    ep_rew_mean          | 62.5        |
# | time/                   |             |
# |    fps                  | 1499        |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011748478 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0255     |
# |    value_loss           | 40.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.3        |
# |    ep_rew_mean          | 86.3        |
# | time/                   |             |
# |    fps                  | 1481        |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011465507 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.581      |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 43.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 112          |
# |    ep_rew_mean          | 112          |
# | time/                   |              |
# |    fps                  | 1449         |
# |    iterations           | 6            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0110755805 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.57        |
# |    explained_variance   | 0.598        |
# |    learning_rate        | 0.0003       |
# ...
# |    time_elapsed         | 38          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008844385 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.02        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 2189        |
# |    iterations           | 7           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008268484 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.509      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.865       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00622    |
# |    value_loss           | 4.14        |
# -----------------------------------------
# (200.0, 0.0)
# Environment number 8
# Using cuda device
# Logging to /home/kchn/rlp/cartpole/multi/Training/Logs/PPO_11
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | 22.3     |
# | time/              |          |
# |    fps             | 13562    |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.7       |
# |    ep_rew_mean          | 37.7       |
# | time/                   |            |
# |    fps                  | 3254       |
# |    iterations           | 2          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01577675 |
# |    clip_fraction        | 0.259      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.68      |
# |    explained_variance   | -0.000212  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.02       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0293    |
# |    value_loss           | 13.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.1        |
# |    ep_rew_mean          | 79.1        |
# | time/                   |             |
# |    fps                  | 2595        |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.018747948 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.039      |
# |    value_loss           | 29.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 146        |
# |    ep_rew_mean          | 146        |
# | time/                   |            |
# |    fps                  | 2387       |
# |    iterations           | 4          |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01059706 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.588     |
# |    explained_variance   | 0.396      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.4       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0268    |
# |    value_loss           | 43.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | 187         |
# | time/                   |             |
# |    fps                  | 2277        |
# |    iterations           | 5           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013497226 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 31.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2215        |
# |    iterations           | 6           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011948302 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.511      |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00782    |
# |    value_loss           | 11          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2174        |
# |    iterations           | 7           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.004643688 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.493      |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.74        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 3.65        |
# -----------------------------------------
# (200.0, 0.0)
# Environment number 9
# Using cuda device
# Logging to /home/kchn/rlp/cartpole/multi/Training/Logs/PPO_12
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | 22.4     |
# | time/              |          |
# |    fps             | 15156    |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 18432    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42.1       |
# |    ep_rew_mean          | 42.1       |
# | time/                   |            |
# |    fps                  | 3537       |
# |    iterations           | 2          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01570051 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.679     |
# |    explained_variance   | -0.000332  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.4        |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0285    |
# |    value_loss           | 12.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.9        |
# |    ep_rew_mean          | 73.9        |
# | time/                   |             |
# |    fps                  | 2828        |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.020371962 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0399     |
# |    value_loss           | 27          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 153         |
# | time/                   |             |
# |    fps                  | 2556        |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013333077 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0264     |
# |    value_loss           | 40.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 185         |
# | time/                   |             |
# |    fps                  | 2424        |
# |    iterations           | 5           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009704954 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 27.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 200        |
# | time/                   |            |
# |    fps                  | 2335       |
# |    iterations           | 6          |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.01502328 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.512     |
# |    explained_variance   | 0.753      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.27       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0111    |
# |    value_loss           | 12.4       |
# ----------------------------------------
# (200.0, 0.0)
# Environment number 10
# Using cuda device
# Logging to /home/kchn/rlp/cartpole/multi/Training/Logs/PPO_13
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | 22.3     |
# | time/              |          |
# |    fps             | 16431    |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 20480    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.7        |
# |    ep_rew_mean          | 35.7        |
# | time/                   |             |
# |    fps                  | 3564        |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015040169 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | 0.000132    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.7         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.3        |
# |    ep_rew_mean          | 95.3        |
# | time/                   |             |
# |    fps                  | 2830        |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.020201096 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 28.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | 147         |
# | time/                   |             |
# |    fps                  | 2559        |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011941886 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0244     |
# |    value_loss           | 37.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 189         |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 2386        |
# |    iterations           | 5           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.009648646 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.548      |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 30.4        |
# -----------------------------------------
# (200.0, 0.0)
