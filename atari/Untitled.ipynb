# %%
import gym
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import os

# %%
env = make_atari_env('Breakout-v0', n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=1)

# %%
log_path = os.path.join('/home/kchn/rlp/atari/multi/Training', 'Logs')
save_path = os.path.join('/home/kchn/rlp/atari/multi/saved_models', 'Logs')
model = A2C('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=6.0, verbose=1)
eval_callback = EvalCallback(
    env,
    callback_on_new_best=stop_callback,
    eval_freq=10000,
    best_model_save_path=save_path,
    verbose=1
)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=1000000, callback=eval_callback)
# Out:
# Logging to /home/kchn/rlp/atari/multi/Training/Logs/A2C_30
# /home/kchn/.local/lib/python3.10/site-packages/stable_baselines3/common/callbacks.py:345: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7fcef4669600> != <stable_baselines3.common.vec_env.vec_frame_stack.VecFrameStack object at 0x7fcef4669690>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 264      |
# |    ep_rew_mean        | 1.3      |
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -10      |
# ...

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /home/kchn/.local/lib/python3.10/site-packages/gym/envs/atari/environment.py:267: UserWarning: WARN: We strongly suggest supplying `render_mode` when constructing your environment, e.g., gym.make(ID, render_mode='human'). Using `render_mode` provides access to proper scaling, audio support, and proper framerates.
#   logger.warn(
# (3.6, 2.009975124224178)

# %%
env.close()

# %%
environment_name = 'Breakout-v0'
log_path = os.path.join('/home/kchn/rlp/atari/multi/Training', 'Logs')

# %%
for i in range(1, 2):
    print("Environment number", i)
    env = make_atari_env(environment_name, n_envs=i, seed=0)
    env = VecFrameStack(env, n_stack=i)
    mdl = A2C('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
    mdl.learn(total_timesteps=100000)
    print(evaluate_policy(mdl, env, n_eval_episodes=10, render=True))
# Out:
# Environment number 1
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to /home/kchn/rlp/atari/multi/Training/Logs/A2C_29
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 309      |
# |    ep_rew_mean        | 2.12     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -32.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0072  |
# |    value_loss         | 0.000319 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 290      |
# |    ep_rew_mean        | 1.72     |
# ...

# %%
i = 0
for mdl, env in zip(model, menv):
    evaluate_policy(mdl, env, n_eval_episodes=10, render=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 i = 0
# ----> 2 for mdl, env in zip(model, menv):
#       3     evaluate_policy(mdl, env, n_eval_episodes=10, render=True)
#
# NameError: name 'model' is not defined
