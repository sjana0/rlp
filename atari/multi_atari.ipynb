# %%
import gym
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import os

# %%
environment_name = 'Breakout-v0'
log_path = os.path.join('/home/kchn/rlp/atari/multi/Training', 'Logs')
save_path = os.path.join('/home/kchn/rlp/atari/multi/Training', 'Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=6, verbose=1)
eval_callback = EvalCallback(
    env,
    callback_on_new_best=stop_callback,
    eval_freq=10000,
    best_model_save_path=save_path,
    verbose=1
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 stop_callback = StopTrainingOnRewardThreshold(reward_threshold=6, verbose=1)
#       2 eval_callback = EvalCallback(
# ----> 3     env,
#       4     callback_on_new_best=stop_callback,
#       5     eval_freq=10000,
#       6     best_model_save_path=save_path,
#       7     verbose=1
#       8 )
#
# NameError: name 'env' is not defined

# %%
for i in range(1, 11):
    print("Environment number", i)
    env = make_atari_env(environment_name, n_envs=i, seed=0)
    env = VecFrameStack(env, n_stack=i)
    mdl = A2C('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
    mdl.learn(total_timesteps=100000)
    print(evaluate_policy(mdl, env, n_eval_episodes=10, render=True))
    env.close()
# Out:
# Environment number 1
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to /home/kchn/rlp/atari/multi/Training/Logs/A2C_34
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 324      |
# |    ep_rew_mean        | 2.43     |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.229    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.185   |
# |    value_loss         | 0.0262   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 343      |
# |    ep_rew_mean        | 2.86     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | -2.31    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.00771  |
# |    value_loss         | 7.64e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 308      |
# |    ep_rew_mean        | 2.2      |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | -0.00956 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.116   |
# |    value_loss         | 0.0114   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 306      |
# |    ep_rew_mean        | 2.09     |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.536    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0388   |
# |    value_loss         | 0.00102  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 308      |
# |    ep_rew_mean        | 2.1      |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 500      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -142     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0299  |
# |    value_loss         | 0.00108  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 314      |
# |    ep_rew_mean        | 2.29     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.131    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.14     |
# |    value_loss         | 0.796    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 309      |
# |    ep_rew_mean        | 2.17     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.147    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.472    |
# |    value_loss         | 0.319    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 302      |
# |    ep_rew_mean        | 2.01     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 800      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.314   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0392  |
# |    value_loss         | 0.00229  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 308      |
# |    ep_rew_mean        | 2.09     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 900      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.0996  |
# |    explained_variance | 0.237    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0113   |
# |    value_loss         | 0.579    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 307      |
# |    ep_rew_mean        | 2.06     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.777   |
# |    explained_variance | 0.907    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0185   |
# |    value_loss         | 0.000386 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 302       |
# |    ep_rew_mean        | 1.95      |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 1100      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.0286   |
# |    explained_variance | -121      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -2.21e-05 |
# |    value_loss         | 0.00012   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 299       |
# |    ep_rew_mean        | 1.89      |
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 1200      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | -8.95e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 0.00315   |
# |    value_loss         | 1.2e-05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 298      |
# |    ep_rew_mean        | 1.87     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 1300     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.725   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0963  |
# |    value_loss         | 0.00891  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 297      |
# |    ep_rew_mean        | 1.82     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 1400     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.626    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.145   |
# |    value_loss         | 0.0117   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 297      |
# |    ep_rew_mean        | 1.81     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 1500     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.389   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0952  |
# |    value_loss         | 0.00744  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 294       |
# |    ep_rew_mean        | 1.77      |
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 1600      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -2.13e+14 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.0214   |
# |    value_loss         | 0.000182  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 290       |
# |    ep_rew_mean        | 1.65      |
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 1700      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.346    |
# |    explained_variance | -7.18e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.000339  |
# |    value_loss         | 0.00041   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 293      |
# |    ep_rew_mean        | 1.69     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 1800     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.161   |
# |    explained_variance | 0.786    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.000701 |
# |    value_loss         | 0.000761 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 292      |
# |    ep_rew_mean        | 1.71     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 1900     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.229   |
# |    explained_variance | 0.822    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.00374 |
# |    value_loss         | 0.00766  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 292      |
# |    ep_rew_mean        | 1.7      |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 2000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0454  |
# |    explained_variance | 0.0326   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00355  |
# |    value_loss         | 0.299    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 290      |
# |    ep_rew_mean        | 1.68     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 2100     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.146   |
# |    explained_variance | 0.748    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.000702 |
# |    value_loss         | 0.00199  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 294       |
# |    ep_rew_mean        | 1.76      |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 2200      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.00887  |
# |    explained_variance | 0.888     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -0.000145 |
# |    value_loss         | 0.0948    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 1.8      |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 2300     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.0203  |
# |    explained_variance | -56.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 1.71e-05 |
# |    value_loss         | 7.9e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 294      |
# |    ep_rew_mean        | 1.78     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 2400     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.0579  |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.00029 |
# |    value_loss         | 0.0111   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 297      |
# |    ep_rew_mean        | 1.83     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 2500     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.837   |
# |    explained_variance | 0.0469   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.0422  |
# |    value_loss         | 0.00121  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 297       |
# |    ep_rew_mean        | 1.84      |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 2600      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.00954  |
# |    explained_variance | -2.25e+13 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -0.000223 |
# |    value_loss         | 0.0408    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 299      |
# |    ep_rew_mean        | 1.86     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 2700     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.12    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.00087  |
# |    value_loss         | 0.00185  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 301      |
# |    ep_rew_mean        | 1.91     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 2800     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.0214  |
# |    explained_variance | -161     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00116  |
# |    value_loss         | 0.0858   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 303      |
# |    ep_rew_mean        | 1.93     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 2900     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.146   |
# |    explained_variance | -0.372   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.00489 |
# |    value_loss         | 0.394    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 307      |
# |    ep_rew_mean        | 2        |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 3000     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | -0.772   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00341  |
# |    value_loss         | 8.61e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 309       |
# |    ep_rew_mean        | 2.02      |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 3100      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -1.22     |
# |    explained_variance | -4.58e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | 0.016     |
# |    value_loss         | 0.000353  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 303      |
# |    ep_rew_mean        | 1.95     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 3200     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.925   |
# |    explained_variance | -136     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.362   |
# |    value_loss         | 0.161    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 305      |
# |    ep_rew_mean        | 1.99     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 3300     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.961   |
# |    explained_variance | -203     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.269    |
# |    value_loss         | 0.0527   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 301      |
# |    ep_rew_mean        | 1.91     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 3400     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | -0.196   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00139  |
# |    value_loss         | 0.00193  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 299       |
# |    ep_rew_mean        | 1.88      |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 3500      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -1.13     |
# |    explained_variance | -3.79e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | 0.00457   |
# |    value_loss         | 7.28e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 295       |
# |    ep_rew_mean        | 1.82      |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 3600      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.738    |
# |    explained_variance | -2.63e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | 0.00258   |
# |    value_loss         | 0.000755  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 296      |
# |    ep_rew_mean        | 1.83     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 3700     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | -1.69    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.00202 |
# |    value_loss         | 0.000632 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 296      |
# |    ep_rew_mean        | 1.85     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 3800     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.345   |
# |    explained_variance | -20.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.0134   |
# |    value_loss         | 0.0244   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 292       |
# |    ep_rew_mean        | 1.79      |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 3900      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -1.25     |
# |    explained_variance | -3.18e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -0.0258   |
# |    value_loss         | 0.00214   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 289      |
# |    ep_rew_mean        | 1.74     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 4000     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.512   |
# |    explained_variance | -1.24    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00744 |
# |    value_loss         | 0.0204   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 287      |
# |    ep_rew_mean        | 1.7      |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 4100     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.53    |
# |    explained_variance | -536     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.0165   |
# |    value_loss         | 0.0034   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 291       |
# |    ep_rew_mean        | 1.77      |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 4200      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | -1.45e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -0.00534  |
# |    value_loss         | 7.2e-05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 291      |
# |    ep_rew_mean        | 1.77     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 4300     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -105     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.227   |
# |    value_loss         | 0.088    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 290      |
# |    ep_rew_mean        | 1.75     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 4400     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | -74.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.00332 |
# |    value_loss         | 0.000157 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 292      |
# |    ep_rew_mean        | 1.78     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 4500     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.778   |
# |    explained_variance | 0.621    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.0376   |
# |    value_loss         | 0.0769   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 1.83     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 4600     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.958   |
# |    explained_variance | -0.772   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.0881  |
# |    value_loss         | 0.0101   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 296      |
# |    ep_rew_mean        | 1.85     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 4700     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.652   |
# |    explained_variance | -4.2e+03 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0121  |
# |    value_loss         | 0.00152  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 1.82     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 4800     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.949   |
# |    explained_variance | 0.243    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0137  |
# |    value_loss         | 0.000837 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 301       |
# |    ep_rew_mean        | 1.93      |
# | time/                 |           |
# |    fps                | 252       |
# |    iterations         | 4900      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -1.26     |
# |    explained_variance | -9.49e+13 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -0.0393   |
# |    value_loss         | 0.00111   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 296      |
# |    ep_rew_mean        | 1.84     |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 5000     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.87    |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.0086   |
# |    value_loss         | 0.00516  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 300      |
# |    ep_rew_mean        | 1.91     |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 5100     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.934   |
# |    explained_variance | -14.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.277    |
# |    value_loss         | 0.0646   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 1.83     |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 5200     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.707   |
# |    explained_variance | -2.86    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.037    |
# |    value_loss         | 0.00156  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 293      |
# |    ep_rew_mean        | 1.79     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 5300     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -1.2     |
# |    explained_variance | 0.128    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.00304 |
# |    value_loss         | 8.27e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 292      |
# |    ep_rew_mean        | 1.78     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 5400     |
# |    time_elapsed       | 106      |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | -0.926   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.0233  |
# |    value_loss         | 0.000383 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 294      |
# |    ep_rew_mean        | 1.82     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 5500     |
# |    time_elapsed       | 108      |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.0145  |
# |    value_loss         | 0.000344 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 297      |
# |    ep_rew_mean        | 1.85     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 5600     |
# |    time_elapsed       | 110      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.964   |
# |    explained_variance | -50      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.324    |
# |    value_loss         | 0.126    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 297      |
# |    ep_rew_mean        | 1.85     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 5700     |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.983   |
# |    explained_variance | -13.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.409    |
# |    value_loss         | 0.257    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 1.8      |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 5800     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | -38.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.0314  |
# |    value_loss         | 0.0226   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 297      |
# |    ep_rew_mean        | 1.85     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 5900     |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.889   |
# |    explained_variance | -42.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.00316  |
# |    value_loss         | 0.000105 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 292      |
# |    ep_rew_mean        | 1.76     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 6000     |
# |    time_elapsed       | 118      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.916   |
# |    explained_variance | -18.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.0503  |
# |    value_loss         | 0.022    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 296      |
# |    ep_rew_mean        | 1.83     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 6100     |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.802   |
# |    explained_variance | -749     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.0151   |
# |    value_loss         | 0.000464 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 1.8      |
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 6200     |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.782   |
# |    explained_variance | 0.862    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.0413   |
# |    value_loss         | 0.0351   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 298       |
# |    ep_rew_mean        | 1.84      |
# | time/                 |           |
# |    fps                | 254       |
# |    iterations         | 6300      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -0.88     |
# |    explained_variance | -5.03e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -0.00678  |
# |    value_loss         | 0.000151  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 302      |
# |    ep_rew_mean        | 1.92     |
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 6400     |
# |    time_elapsed       | 125      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.741   |
# |    explained_variance | -11      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.147   |
# |    value_loss         | 0.00887  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 303      |
# |    ep_rew_mean        | 1.92     |
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 6500     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.647   |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.072   |
# |    value_loss         | 0.0116   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 304      |
# |    ep_rew_mean        | 1.91     |
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 6600     |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.576   |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.00722 |
# |    value_loss         | 0.00117  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 301      |
# |    ep_rew_mean        | 1.86     |
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 6700     |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.58    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.00564 |
# |    value_loss         | 0.000729 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 301      |
# |    ep_rew_mean        | 1.87     |
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 6800     |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.366   |
# |    explained_variance | -24.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.00167 |
# |    value_loss         | 0.00512  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 305      |
# |    ep_rew_mean        | 1.95     |
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 6900     |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.32    |
# |    explained_variance | 0.352    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.00637  |
# |    value_loss         | 0.00464  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 306      |
# |    ep_rew_mean        | 1.97     |
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 7000     |
# |    time_elapsed       | 136      |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | 0.306    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.00121  |
# |    value_loss         | 0.00115  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 305      |
# |    ep_rew_mean        | 1.93     |
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 7100     |
# |    time_elapsed       | 138      |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.338   |
# |    explained_variance | 0.977    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 0.0046   |
# |    value_loss         | 0.0044   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 308      |
# |    ep_rew_mean        | 2        |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 7200     |
# |    time_elapsed       | 140      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.497   |
# |    explained_variance | -1.36    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.0154  |
# |    value_loss         | 0.00176  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 311      |
# |    ep_rew_mean        | 2.04     |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 7300     |
# |    time_elapsed       | 142      |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.447   |
# |    explained_variance | 0.893    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.00285  |
# |    value_loss         | 0.000392 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 306      |
# |    ep_rew_mean        | 1.95     |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 7400     |
# |    time_elapsed       | 144      |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.165   |
# |    explained_variance | -18.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.00726  |
# |    value_loss         | 0.0349   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 308      |
# |    ep_rew_mean        | 1.99     |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 7500     |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.268   |
# |    explained_variance | -0.976   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.00188 |
# |    value_loss         | 0.00172  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 303      |
# |    ep_rew_mean        | 1.88     |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 7600     |
# |    time_elapsed       | 148      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.406   |
# |    explained_variance | -4.02    |
# ...
# |    value_loss         | 0.129    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 416      |
# |    ep_rew_mean        | 4.19     |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 1800     |
# |    time_elapsed       | 418      |
# |    total_timesteps    | 81000    |
# | train/                |          |
# |    entropy_loss       | -0.521   |
# |    explained_variance | 0.822    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0422   |
# |    value_loss         | 0.138    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 430      |
# |    ep_rew_mean        | 4.42     |
# | time/                 |          |
# |    fps                | 191      |
# |    iterations         | 1900     |
# |    time_elapsed       | 446      |
# |    total_timesteps    | 85500    |
# | train/                |          |
# |    entropy_loss       | -0.59    |
# |    explained_variance | 0.696    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0146  |
# |    value_loss         | 0.0476   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 441      |
# |    ep_rew_mean        | 4.85     |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 2000     |
# |    time_elapsed       | 473      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0.661    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0707  |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 467      |
# |    ep_rew_mean        | 5.58     |
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 2100     |
# |    time_elapsed       | 500      |
# |    total_timesteps    | 94500    |
# | train/                |          |
# |    entropy_loss       | -0.799   |
# |    explained_variance | 0.895    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.0957   |
# |    value_loss         | 0.0882   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 471      |
# |    ep_rew_mean        | 5.65     |
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 2200     |
# |    time_elapsed       | 527      |
# |    total_timesteps    | 99000    |
# | train/                |          |
# |    entropy_loss       | -0.588   |
# |    explained_variance | 0.901    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0521   |
# |    value_loss         | 0.0631   |
# ------------------------------------
# (6.6, 1.3564659966250536)
# Environment number 10
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to /home/kchn/rlp/atari/multi/Training/Logs/A2C_43
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 278      |
# |    ep_rew_mean        | 1.46     |
# | time/                 |          |
# |    fps                | 152      |
# |    iterations         | 100      |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0.337    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0824   |
# |    value_loss         | 0.256    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 270      |
# |    ep_rew_mean        | 1.34     |
# | time/                 |          |
# |    fps                | 151      |
# |    iterations         | 200      |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | -0.25    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.224   |
# |    value_loss         | 0.211    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 277      |
# |    ep_rew_mean        | 1.45     |
# | time/                 |          |
# |    fps                | 151      |
# |    iterations         | 300      |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.306    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0948  |
# |    value_loss         | 0.132    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 279      |
# |    ep_rew_mean        | 1.49     |
# | time/                 |          |
# |    fps                | 152      |
# |    iterations         | 400      |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.463    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0317   |
# |    value_loss         | 0.0745   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 300      |
# |    ep_rew_mean        | 1.88     |
# | time/                 |          |
# |    fps                | 152      |
# |    iterations         | 500      |
# |    time_elapsed       | 163      |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.669    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.109   |
# |    value_loss         | 0.0379   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 317      |
# |    ep_rew_mean        | 2.15     |
# | time/                 |          |
# |    fps                | 153      |
# |    iterations         | 600      |
# |    time_elapsed       | 195      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.784    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.058   |
# |    value_loss         | 0.141    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 338      |
# |    ep_rew_mean        | 2.66     |
# | time/                 |          |
# |    fps                | 154      |
# |    iterations         | 700      |
# |    time_elapsed       | 226      |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | 0.798    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.126   |
# |    value_loss         | 0.0989   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 351      |
# |    ep_rew_mean        | 2.97     |
# | time/                 |          |
# |    fps                | 155      |
# |    iterations         | 800      |
# |    time_elapsed       | 257      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.454    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0189  |
# |    value_loss         | 0.115    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 378      |
# |    ep_rew_mean        | 3.56     |
# | time/                 |          |
# |    fps                | 156      |
# |    iterations         | 900      |
# |    time_elapsed       | 287      |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | 0.856    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.133   |
# |    value_loss         | 0.0591   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 380      |
# |    ep_rew_mean        | 3.65     |
# | time/                 |          |
# |    fps                | 156      |
# |    iterations         | 1000     |
# |    time_elapsed       | 318      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.91    |
# |    explained_variance | 0.858    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.025    |
# |    value_loss         | 0.073    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 415      |
# |    ep_rew_mean        | 4.34     |
# | time/                 |          |
# |    fps                | 157      |
# |    iterations         | 1100     |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 55000    |
# | train/                |          |
# |    entropy_loss       | -0.506   |
# |    explained_variance | 0.878    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0876  |
# |    value_loss         | 0.1      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 437      |
# |    ep_rew_mean        | 4.83     |
# | time/                 |          |
# |    fps                | 158      |
# |    iterations         | 1200     |
# |    time_elapsed       | 378      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.998   |
# |    explained_variance | 0.872    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0566   |
# |    value_loss         | 0.057    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 442      |
# |    ep_rew_mean        | 4.99     |
# | time/                 |          |
# |    fps                | 159      |
# |    iterations         | 1300     |
# |    time_elapsed       | 408      |
# |    total_timesteps    | 65000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.444    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.121   |
# |    value_loss         | 0.316    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 435      |
# |    ep_rew_mean        | 4.83     |
# | time/                 |          |
# |    fps                | 159      |
# |    iterations         | 1400     |
# |    time_elapsed       | 438      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -0.98    |
# |    explained_variance | 0.873    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.0104   |
# |    value_loss         | 0.096    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 428      |
# |    ep_rew_mean        | 4.68     |
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 1500     |
# |    time_elapsed       | 468      |
# |    total_timesteps    | 75000    |
# | train/                |          |
# |    entropy_loss       | -1.19    |
# |    explained_variance | 0.925    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0577  |
# |    value_loss         | 0.0641   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 445      |
# |    ep_rew_mean        | 4.97     |
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 1600     |
# |    time_elapsed       | 498      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.6     |
# |    explained_variance | 0.85     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.00983 |
# |    value_loss         | 0.0644   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 447      |
# |    ep_rew_mean        | 4.97     |
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 1700     |
# |    time_elapsed       | 528      |
# |    total_timesteps    | 85000    |
# | train/                |          |
# |    entropy_loss       | -0.817   |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.0167   |
# |    value_loss         | 0.0308   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 448      |
# |    ep_rew_mean        | 5.09     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 1800     |
# |    time_elapsed       | 557      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.552   |
# |    explained_variance | 0.93     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.0376  |
# |    value_loss         | 0.108    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 477      |
# |    ep_rew_mean        | 5.61     |
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 1900     |
# |    time_elapsed       | 591      |
# |    total_timesteps    | 95000    |
# | train/                |          |
# |    entropy_loss       | -0.425   |
# |    explained_variance | 0.706    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0412  |
# |    value_loss         | 0.117    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 510      |
# |    ep_rew_mean        | 6.22     |
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 2000     |
# |    time_elapsed       | 621      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.492   |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.00829 |
# |    value_loss         | 0.0386   |
# ------------------------------------
# (8.8, 2.785677655436824)
